# %%
# %run -i C:\Users\OnishiItsuki\PycharmProjects\sketching-nmf\main_apply_data.py
# Out:
# -----------------   START   ------------------
# mode = 2
# start  realdata_3(correction k,r)_V_MU_[n361, m2429, r15, as100, ite5000,seed 0, 1]  >>>>>
#
# seed of V=0  seed of WH=1
#
#
#
# ------------------   NMF   -------------------
# 1 times update  error: 1209666080.9568803
# 100 times update  error: 445193219.17764807
# 200 times update  error: 359202698.22027344
# 300 times update  error: 344181027.6116303
# 400 times update  error: 338552309.43151844
# 500 times update  error: 335338415.88872415
# 600 times update  error: 333121260.988414
# 700 times update  error: 331437940.8830566
# 800 times update  error: 330057450.8938917
# 900 times update  error: 328893150.7507197
# 1000 times update  error: 327884213.39142245
# 1100 times update  error: 327047681.91843057
# 1200 times update  error: 326343717.12526906
# 1300 times update  error: 325722358.4408883
# 1400 times update  error: 325161150.8677613
# 1500 times update  error: 324647633.91328424
# ...
